# %% [markdown]
# <a href="https://colab.research.google.com/github/shreehere/MentorTasks/blob/main/Mentor_Task_Movies(MongoDB).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing MongoClient from pymongo to connect with the Database
# Importing pandas to get the result in Dataframe

from pymongo import MongoClient
import pandas as pd

# %%
#created a variable in the name of "Collection" to connect with MongoClient

Collection=MongoClient("mongodb://jaishree:ssunshines@ac-g9lplzi-shard-00-00.deg5rti.mongodb.net:27017,ac-g9lplzi-shard-00-01.deg5rti.mongodb.net:27017,ac-g9lplzi-shard-00-02.deg5rti.mongodb.net:27017/?ssl=true&replicaSet=atlas-10vvj7-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
#Adding the database "db" 

db=Collection["sample_mflix"]["movies"]

# %%
#Created an empty list and appending the data based on the required conditions

Result=[]
for i in db.find({'$or':[{'$and':[{'year':{'$gte':1950}},{'year':{'$lte':1970}},{"tomatoes.viewer.rating":{'$gt':3}},{"imdb.rating":{'$gt':7}},{"awards.wins":{'$gte':1}},{'genres':{'$in':["Comedy","Fantasy","Horror"]}}]},{'$and':[{'year':{'$gte':2000}},{'year':{'$lte':2015}},{"tomatoes.viewer.rating":{'$gt':3}},{"imdb.rating":{'$gt':7}},{"awards.wins":{'$gte':1}},{'genres':{'$in':["Comedy","Fantasy","Horror"]}}]}]},{"_id":0,"title":1,"directors":1,"cast":1,"imdb":1,"tomatoes":1,"awards":1,"genres":1}):
  Result.append(i)

# %%
# Result in the form of a Data frame
# We have got 988 rows with the conditions specified

pd.DataFrame(Result)
# Out:
#                            genres  \
# 0        [Comedy, Drama, Romance]
# 1    [Animation, Family, Fantasy]
# 2                [Family, Comedy]
# 3                 [Comedy, Drama]
# 4                 [Comedy, Crime]
# ..                            ...
# 983  [Documentary, Comedy, Drama]
# 984                      [Comedy]
# 985               [Comedy, Drama]
# 986               [Comedy, Drama]
# 987               [Comedy, Drama]
#
#                                                   cast  \
# 0    [Judy Holliday, Broderick Crawford, William Ho...
# 1    [Ilene Woods, Eleanor Audley, Verna Felton, Cl...
# 2    [Antje Weisgerber, Peter Mosbacher, Jutta Gènt...
# 3    [James Stewart, Josephine Hull, Peggy Dow, Cha...
# 4    [Burt Lancaster, Dorothy McGuire, Edmund Gwenn...
# ..                                                 ...
# 983  [Seija Airamo, Erkki Broman, Pirjo Mutanen, Ma...
# 984  [Maz Jobrani, John Heard, Deanna Russo, Marsha...
# ...
